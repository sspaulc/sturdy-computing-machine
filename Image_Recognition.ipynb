# %% [markdown]
# <a href="https://colab.research.google.com/github/sspaulc/sturdy-computing-machine/blob/main/Image_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
pip install Pillow

# %%
import tensorflow as tf
import numpy as np

# %%
import tensorflow as tf
import numpy as np

# %%
filename ='/content/pexels-photo-1108099.jpeg'

# %%
import cv2

# %%
ingg= cv2.imread(filename)

# %%
import matplotlib.pyplot as plt
plt.imshow(ingg)

# %%
ingg= cv2.resize(ingg,(224,224))
plt.imshow(ingg)

# %%
plt.imshow(cv2.cvtColor(ingg, cv2.COLOR_BGR2RGB))

# %%
#Load deep learning model

# %%
mobile= tf.keras.applications.mobilenet_v2.MobileNetV2() #deep learning architecture for image classification pre-trained
# Out:
# ...
# 14540800/14536120 [==============================] - 0s 0us/step

# %%
#Creating a model
#Training a model
#Test and validation 
#Predict

# %%
#Pre-processing of the image
from tensorflow.keras.preprocessing import image
ing= image.load_img(filename,target_size=(224,224))
plt.imshow(ing)

# %%
resized_image= image.img_to_array(ing)
final_image= np.expand_dims(resized_image,axis=0)
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions=mobile.predict(final_image)

from tensorflow.keras.applications import imagenet_utils
results=imagenet_utils.decode_predictions(predictions)
print(results)
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# [[('n02099601', 'golden_retriever', 0.6707864), ('n02099712', 'Labrador_retriever', 0.06796821), ('n02113799', 'standard_poodle', 0.04617534), ('n02113712', 'miniature_poodle', 0.011994287), ('n02091635', 'otterhound', 0.009042499)]]
